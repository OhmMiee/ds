# %% [markdown]
# ## seaborn
# #### seaborn is a library that uses Matplotlib underneath to plot graphs.
# #### Matplotlib is a low level graph plotting library in python that serves as a visualization utility.
# ##### https://seaborn.pydata.org/tutorial.html

# %% [markdown]
# ## barplot
# **A bar plot or bar chart is a chart or graph that presents categorical data with rectangular bars with heights or lengths proportional to the values that they represent. The bars can be plotted vertically or horizontally.**

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
# %matplotlib inline 
# %config InlineBackend.figure_format='retina'

# %%
url='https://github.com/mathawanup/learn_dataset/raw/master/car_mpg.csv'
df=pd.read_csv(url)
df
# Out:
#     manufacturer   model  displ  year  cyl       trans    drv  cty  hwy fl  \
# 0           audi      a4    1.8  1999    4    auto(l5)  front   18   29  p
# 1           audi      a4    1.8  1999    4  manual(m5)  front   21   29  p
# 2           audi      a4    2.0  2008    4  manual(m6)  front   20   31  p
# 3           audi      a4    2.0  2008    4    auto(av)  front   21   30  p
# 4           audi      a4    2.8  1999    6    auto(l5)  front   16   26  p
# ..           ...     ...    ...   ...  ...         ...    ...  ...  ... ..
# 229   volkswagen  passat    2.0  2008    4    auto(s6)  front   19   28  p
# 230   volkswagen  passat    2.0  2008    4  manual(m6)  front   21   29  p
# 231   volkswagen  passat    2.8  1999    6    auto(l5)  front   16   26  p
# 232   volkswagen  passat    2.8  1999    6  manual(m5)  front   18   26  p
# 233   volkswagen  passat    3.6  2008    6    auto(s6)  front   17   26  p
#
#        class    gear
# 0    compact    auto
# 1    compact  manual
# 2    compact  manual
# 3    compact    auto
# 4    compact    auto
# ..       ...     ...
# 229  midsize    auto
# 230  midsize  manual
# 231  midsize    auto
# 232  midsize  manual
# 233  midsize    auto
#
# [234 rows x 12 columns]

# %%
sns.barplot(x='gear', y='cty', data=df)
# Out:
# <AxesSubplot:xlabel='gear', ylabel='cty'>

# %%
sns.barplot(x='gear', y='cty', data=df)  ;

# %%
sns.barplot(x='gear', y='cty', data=df, hue='drv')
# Out:
# <AxesSubplot:xlabel='gear', ylabel='cty'>

# %%
df.groupby('drv')['cty'].describe()
# Out:
#          count       mean       std   min   25%   50%   75%   max
# drv
# 4-wheel  103.0  14.330097  2.874459   9.0  13.0  14.0  16.0  21.0
# front    106.0  19.971698  3.626510  11.0  18.0  19.0  21.0  35.0
# rear      25.0  14.080000  2.215852  11.0  12.0  15.0  15.0  18.0

# %%
sns.barplot(x='drv', y='cty', data=df)
# Out:
# <AxesSubplot:xlabel='drv', ylabel='cty'>

# %%
avg=df.cty.mean() 
sns.barplot(x='drv', y='cty', data=df)
plt.axhline(y=avg, color='red', linestyle='--')

# %%
avg=df.cty.mean()
sns.barplot(x='drv', y='cty', data=df, 
            hue='gear',
            palette='Set1', 
            ci=None,
            ) 
plt.axhline(y=avg, color='red', linestyle='--')
# https://seaborn.pydata.org/generated/seaborn.color_palette.html

# %%
avg=df.cty.mean()
plt.figure(figsize=(10,7)) 
sns.barplot(x='drv', y='cty', data=df, 
            hue='gear',
            palette='Set1', 
            ci=None,
            )
plt.axhline(y=avg, color='red', linestyle='--')

# %%
plt.figure(figsize=(8,6))  
sns.barplot(x='drv', y='cty', data=df,
            hue='gear', 
            ci=None,
            palette=['#dd0000', 'plum'])  # palette  https://matplotlib.org/3.1.0/gallery/color/named_colors.html
# Out:
# <AxesSubplot:xlabel='drv', ylabel='cty'>

# %%
plt.figure(figsize=(8,6)) 
sns.barplot(x='drv', y='cty', data=df,
            hue='gear', 
            ci=None,
            palette=['#dd0000', 'plum'])  # palette  https://matplotlib.org/3.1.0/gallery/color/named_colors.html
plt.xlabel('')
plt.ylabel('city miles per gallon') 
plt.title('fuel efficiency by drive wheels')
# Out:
# Text(0.5, 1.0, 'fuel efficiency by drive wheels')

# %%
sns.factorplot(x='drv', y='cty', data=df,ci=None,
               hue="gear", 
               col="year",
               kind="bar",
               height=4, aspect=1);
# Out:
# C:\Users\User\anaconda3\lib\site-packages\seaborn\categorical.py:3704: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)

# %%
df['class'].unique()
# Out:
# array(['compact', 'midsize', 'suv', '2seater', 'minivan', 'pickup',
#        'subcompact'], dtype=object)

# %%
df[df['class'].str.match('compact|suv|midsize')].sample(10)
# Out:
#     manufacturer                   model  displ  year  cyl       trans  \
# 199       toyota  land cruiser wagon 4wd    5.7  2008    8    auto(s6)
# 141       nissan                  altima    2.4  1999    4  manual(m5)
# 3           audi                      a4    2.0  2008    4    auto(av)
# 76          ford          expedition 2wd    5.4  2008    8    auto(l6)
# 178       toyota             4runner 4wd    4.7  2008    8    auto(l5)
# 156      pontiac              grand prix    3.8  1999    6    auto(l4)
# 231   volkswagen                  passat    2.8  1999    6    auto(l5)
# 8           audi              a4 quattro    1.8  1999    4    auto(l5)
# 123         jeep      grand cherokee 4wd    3.7  2008    6    auto(l5)
# 138      mercury         mountaineer 4wd    4.0  2008    6    auto(l5)
#
#          drv  cty  hwy fl    class    gear
# 199  4-wheel   13   18  r      suv    auto
# 141    front   21   29  r  compact  manual
# 3      front   21   30  p  compact    auto
# 76      rear   12   18  r      suv    auto
# 178  4-wheel   14   17  r      suv    auto
# 156    front   17   27  r  midsize    auto
# 231    front   16   26  p  midsize    auto
# 8    4-wheel   16   25  p  compact    auto
# 123  4-wheel   15   19  r      suv    auto
# 138  4-wheel   13   19  r      suv    auto

# %%
sns.factorplot(x='drv', y='cty', data=df[df['class'].str.match('compact|suv|midsize')],
               hue='gear', 
               row='year',
               col='class',
               kind='bar',
               ci=None,
               palette=['deepskyblue', 'tomato'],
               height=3, aspect=1);
# Out:
# C:\Users\User\anaconda3\lib\site-packages\seaborn\categorical.py:3704: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
