# %% [markdown]
# ## seaborn
# #### seaborn is a library that uses Matplotlib underneath to plot graphs.
# #### Matplotlib is a low level graph plotting library in python that serves as a visualization utility.
# ##### https://seaborn.pydata.org/tutorial.html

# %% [markdown]
# ## lineplot

# %% [markdown]
# **a line plot with the possibility of several semantic groupings. The relationship between x and y can be shown for different subsets of the data using the hue, size, and style parameters.**

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
# %config InlineBackend.figure_format='retina'

# %%
url='https://github.com/mathawanup/learn_dataset/raw/master/tuition_graduate.csv'
df=pd.read_csv(url)
df
# Out:
#      academic.year                      school   cost
# 0             1985              Business (MBA)  10000
# 1             1986              Business (MBA)  10750
# 2             1987              Business (MBA)  11900
# 3             1988              Business (MBA)  13300
# 4             1989              Business (MBA)  14250
# ..             ...                         ...    ...
# 292           2013  Public Health (1-Year MPH)  42160
# 293           2014  Public Health (1-Year MPH)  45900
# 294           2015  Public Health (1-Year MPH)  50320
# 295           2016  Public Health (1-Year MPH)  55125
# 296           2017  Public Health (1-Year MPH)  56880
#
# [297 rows x 3 columns]

# %%
df.school.unique()
# Out:
# array(['Business (MBA)', 'Design', 'Divinity', 'Education', 'GSAS',
#        'Government', 'Law', 'Medical/Dental',
#        'Public Health (1-Year MPH)'], dtype=object)

# %%
sns.lineplot(data=df,
             x='academic.year', y='cost', 
             hue='school')
# Out:
# <AxesSubplot:xlabel='academic.year', ylabel='cost'>

# %%
plt.figure(figsize=(10,10))
sns.lineplot(data=df, x='academic.year', y='cost', hue='school')
# Out:
# <AxesSubplot:xlabel='academic.year', ylabel='cost'>

# %%
data1 = df[df.school.str.match('Business|Design|Law')]

# %%
plt.figure(figsize=(10,10))
sns.lineplot(data=data1 , x='academic.year', y='cost', hue='school')
# Out:
# <AxesSubplot:xlabel='academic.year', ylabel='cost'>

# %%
# plt.figure(figsize=(10,10))
sns.relplot(data=df, x='academic.year', y='cost', hue='school', col='school', kind='line')

# %%
sns.relplot(data=df, x='academic.year', y='cost', hue='school', col='school', kind='line', col_wrap=3)

# %%
sns.set_context('notebook', font_scale=1.6)
sns.relplot(data=df, x='academic.year', y='cost', hue='school', col='school', kind='line', col_wrap=3)
